# %% [markdown]
# <h1 align=center><font size = 5>The battle of neighborhoods in Benin</font></h1>

# %% [markdown]
# #### Import the necessary Libraries

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

from bs4 import BeautifulSoup
import requests
import pandas as pd

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# #### Scrape the information about Benin Department Borough and Region

# %%
source = requests.get('https://en.wikipedia.org/wiki/Benin').text

# %%
dep_com_table = pd.read_html(source, header=0, attrs={"class":"wikitable sortable"})[0]
dep_com_table
# Out:
#     Map key  Department Capital[36] [37]  Population (2013)  Area (km2)[38]  \
# 0         2     Alibori            Kandi             868046           26242
# 1         1     Atakora       Natitingou             769337           20499
# 2        10  Atlantique           Allada            1396548            3233
# 3         4      Borgou          Parakou            1202095           25856
# 4         5    Collines      Dassa-Zoumé             716558           13931
# 5         6      Kouffo         Aplahoué             741895            2404
# 6         3       Donga          Djougou             542605           11126
# 7        11    Littoral          Cotonou             678874              79
# 8         9        Mono          Lokossa             495307            1605
# 9        12       Ouémé       Porto-Novo            1096850            1281
# 10        8     Plateau             Pobè             624146            3264
# 11        7         Zou           Abomey             851623            5243
#
#    FormerDepartment Region    Sub-Region
# 0            Borgou  North    North East
# 1           Atakora  North    North West
# 2        Atlantique  South  South Centre
# 3            Borgou  North    North East
# 4               Zou  North  North Centre
# 5              Mono  South    South West
# 6           Atakora  North    North West
# 7        Atlantique  South  South Centre
# 8              Mono  South    South West
# 9             Ouémé  South    South East
# 10            Ouémé  South    South East
# 11              Zou  North  North Centre

# %% [markdown]
# We drop the columns we don't need.

# %%
dep_com_table.columns
# Out:
# Index(['Map key', 'Department', 'Capital[36] [37]', 'Population (2013)',
#        'Area (km2)[38]', 'FormerDepartment', 'Region', 'Sub-Region'],
#       dtype='object')

# %%
Benin_df = dep_com_table.drop(['Map key', 'Population (2013)','Area (km2)[38]', 'FormerDepartment', 'Region']
                        , axis=1)
Benin_df
# Out:
#     Department Capital[36] [37]    Sub-Region
# 0      Alibori            Kandi    North East
# 1      Atakora       Natitingou    North West
# 2   Atlantique           Allada  South Centre
# 3       Borgou          Parakou    North East
# 4     Collines      Dassa-Zoumé  North Centre
# 5       Kouffo         Aplahoué    South West
# 6        Donga          Djougou    North West
# 7     Littoral          Cotonou  South Centre
# 8         Mono          Lokossa    South West
# 9        Ouémé       Porto-Novo    South East
# 10     Plateau             Pobè    South East
# 11         Zou           Abomey  North Centre

# %% [markdown]
# Define a new Benin dataframe with department, Borough, and Region

# %%
Benin_df.rename(columns={"Capital[36] [37]":"Borough", "Sub-Region":"Region"}, inplace=True)
Benin_df
# Out:
#     Department      Borough        Region
# 0      Alibori        Kandi    North East
# 1      Atakora   Natitingou    North West
# 2   Atlantique       Allada  South Centre
# 3       Borgou      Parakou    North East
# 4     Collines  Dassa-Zoumé  North Centre
# 5       Kouffo     Aplahoué    South West
# 6        Donga      Djougou    North West
# 7     Littoral      Cotonou  South Centre
# 8         Mono      Lokossa    South West
# 9        Ouémé   Porto-Novo    South East
# 10     Plateau         Pobè    South East
# 11         Zou       Abomey  North Centre

# %%
print('The Benin_df dataframe has {} departments and {} boroughs.'.format(
        len(Benin_df['Department'].unique()), len(Benin_df['Borough'].unique()))
     )
# Out:
# The Benin_df dataframe has 12 departments and 12 boroughs.

# %% [markdown]
# ### Creating a Geocoder Dataframe

# %% [markdown]
# We choose to build the dataframe with the sample csv file that has the geographical coordinates we obtain from https://www.geopostcodes.com/Benin. You can download it from there.

# %%
# Checking current working directory
os.getcwd()
# Out:
# '/resources/labs/DP0701EN'

# %%
# Changing to new working directory
os.chdir(r'/resources/labs/DP0701EN')

# %%
geo_coord_table=pd.read_csv("benin_places.csv", sep=';')
geo_coord_table.head()
# Out:
#   iso country language          id  region1    region2  region3  region4  \
# 0  BJ   Bénin       FR  1000127461  Alibori  Banikoara      NaN      NaN
# 1  BJ   Bénin       FR  1000127462  Alibori  Banikoara      NaN      NaN
# 2  BJ   Bénin       FR  1000127463  Alibori  Banikoara      NaN      NaN
# 3  BJ   Bénin       FR  1000127464  Alibori  Banikoara      NaN      NaN
# 4  BJ   Bénin       FR  1000127465  Alibori  Banikoara      NaN      NaN
#
#     locality  postcode  suburb   latitude  longitude  elevation   iso2  fips  \
# 0  Banikoara       NaN     NaN  11.293970   2.439285        311  BJ-AL  BN07
# 1   Founougo       NaN     NaN  11.465990   2.539781        287  BJ-AL  BN07
# 2   Gomparou       NaN     NaN  11.328576   2.471542        291  BJ-AL  BN07
# 3    Goumori       NaN     NaN  11.178435   2.299982        304  BJ-AL  BN07
# 4      Kokey       NaN     NaN  11.183333   2.283333        308  BJ-AL  BN07
#
#    nuts      hasc  stat           timezone     utc     dst
# 0   NaN  BJ.AL.BA   NaN  Africa/Porto-Novo  +01:00  +01:00
# 1   NaN  BJ.AL.BA   NaN  Africa/Porto-Novo  +01:00  +01:00
# 2   NaN  BJ.AL.BA   NaN  Africa/Porto-Novo  +01:00  +01:00
# 3   NaN  BJ.AL.BA   NaN  Africa/Porto-Novo  +01:00  +01:00
# 4   NaN  BJ.AL.BA   NaN  Africa/Porto-Novo  +01:00  +01:00

# %%
geo_coord_table.columns
# Out:
# Index(['iso', 'country', 'language', 'id', 'region1', 'region2', 'region3',
#        'region4', 'locality', 'postcode', 'suburb', 'latitude', 'longitude',
#        'elevation', 'iso2', 'fips', 'nuts', 'hasc', 'stat', 'timezone', 'utc',
#        'dst'],
#       dtype='object')

# %%
geo_coord_df = geo_coord_table.drop(['iso' ,'country', 'language', 'id', 'region3','region4','postcode', 'suburb',
                                     'elevation', 'iso2', 'fips', 'nuts', 'hasc', 'stat', 'timezone', 'utc','dst'], axis=1)
geo_coord_df.head()
# Out:
#    region1    region2   locality   latitude  longitude
# 0  Alibori  Banikoara  Banikoara  11.293970   2.439285
# 1  Alibori  Banikoara   Founougo  11.465990   2.539781
# 2  Alibori  Banikoara   Gomparou  11.328576   2.471542
# 3  Alibori  Banikoara    Goumori  11.178435   2.299982
# 4  Alibori  Banikoara      Kokey  11.183333   2.283333

# %% [markdown]
# Conform the columns names

# %%
geo_coord_df.columns
# Out:
# Index(['region1', 'region2', 'locality', 'latitude', 'longitude'], dtype='object')

# %%
geo_coord_df.rename(columns={"country":"Country", "region1":"Department","region2":"Region", "locality":"Neighborhood",
                            "latitude":"Latitude","longitude":"Longitude"}, inplace=True)
geo_coord_df.head()
# Out:
#   Department     Region Neighborhood   Latitude  Longitude
# 0    Alibori  Banikoara    Banikoara  11.293970   2.439285
# 1    Alibori  Banikoara     Founougo  11.465990   2.539781
# 2    Alibori  Banikoara     Gomparou  11.328576   2.471542
# 3    Alibori  Banikoara      Goumori  11.178435   2.299982
# 4    Alibori  Banikoara        Kokey  11.183333   2.283333

# %%
geo_coord_df
# Out:
#     Department         Region                 Neighborhood   Latitude  \
# 0      Alibori      Banikoara                    Banikoara  11.293970
# 1      Alibori      Banikoara                     Founougo  11.465990
# 2      Alibori      Banikoara                     Gomparou  11.328576
# 3      Alibori      Banikoara                      Goumori  11.178435
# 4      Alibori      Banikoara                        Kokey  11.183333
# 5      Alibori      Banikoara                    Kokiborou  11.202332
# 6      Alibori      Banikoara                        Ounet  11.227149
# 7      Alibori      Banikoara                   Sompérékou  11.322743
# 8      Alibori      Banikoara                       Soroko  11.327791
# 9      Alibori      Banikoara                        Toura  11.243611
# 10     Alibori       Gogounou                        Bagou  10.812038
# 11     Alibori       Gogounou                    Gougounou  10.833333
# 12     Alibori       Gogounou                     Gounarou  10.870144
# 13     Alibori       Gogounou                        Ouara  10.866667
# 14     Alibori       Gogounou                         Sori  10.718550
# 15     Alibori       Gogounou            Zoungou-Pantrossi  10.735278
# 16     Alibori          Kandi                  Angaradébou  11.323293
# 17     Alibori          Kandi                     Bensékou  10.985663
# 18     Alibori          Kandi                      Donwari  11.119722
# 19     Alibori          Kandi                      Kandi I  11.128611
# 20     Alibori          Kandi                     Kandi II  11.133097
# 21     Alibori          Kandi                    Kandi III  11.284970
# 22     Alibori          Kandi                     Kassakou  11.081329
# 23     Alibori          Kandi                         Saah  11.176667
# 24     Alibori          Kandi                          Sam  11.033333
# 25     Alibori          Kandi                      Sonsoro  11.087500
# 26     Alibori       Karimama                  Birni-Lafia  11.977746
# 27     Alibori       Karimama                    Bogo-Bogo  12.103834
# 28     Alibori       Karimama                     Karimama  12.066667
# 29     Alibori       Karimama                        Kompa  12.205278
# 30     Alibori       Karimama                       Monsey  12.291481
# 31     Alibori     Malanville                        Garou  11.796756
# 32     Alibori     Malanville                        Guénè  11.722850
# 33     Alibori     Malanville                   Malanville  11.866667
# 34     Alibori     Malanville                    Mandécali  11.662620
# 35     Alibori     Malanville                    Tomboutou  11.854477
# 36     Alibori        Ségbana                      Libantè  10.786405
# 37     Alibori        Ségbana                    Liboussou  10.919943
# 38     Alibori        Ségbana                       Lougou  10.650000
# 39     Alibori        Ségbana                      Ségbana  10.927778
# 40     Alibori        Ségbana                   Sokotindji  10.850147
# 41     Atacora      Boukoumbé                    Boukoumbé  10.183333
# 42     Atacora      Boukoumbé                       Dipoli  10.323478
# 43     Atacora      Boukoumbé                   Korontière  10.271389
# 44     Atacora      Boukoumbé                Kossoucoingou  10.183056
# 45     Atacora      Boukoumbé                        Manta  10.349830
# 46     Atacora      Boukoumbé                        Natta  10.222478
# 47     Atacora      Boukoumbé                       Tabota  10.396233
# 48     Atacora          Cobly                        Cobly  10.492222
# 49     Atacora          Cobly                       Datori  10.403350
# 50     Atacora          Cobly                     Kountori  10.398300
# 51     Atacora          Cobly                       Tapoga  10.572778
# 52     Atacora          Kérou                   Brignamaro  10.740969
# 53     Atacora          Kérou                        Firou  10.914450
# 54     Atacora          Kérou                        Kérou  10.825000
# 55     Atacora          Kérou                     Koabagou  11.063340
# 56     Atacora        Kouandé                        Birni   9.989147
# 57     Atacora        Kouandé                  Chabi-Couma  10.000000
# 58     Atacora        Kouandé                     Fô-Tancé  10.416667
# 59     Atacora        Kouandé                     Guilmaro  10.568514
# 60     Atacora        Kouandé                      Kouandé  10.331723
# 61     Atacora        Kouandé                     Oroukayo  10.302002
# 62     Atacora         Matéri                      Dassari  10.815833
# 63     Atacora         Matéri                      Gouandé  10.782778
# 64     Atacora         Matéri                       Matéri  10.727937
# 65     Atacora         Matéri                         Nodi  10.916667
# 66     Atacora         Matéri                      Tantéga  10.850000
# 67     Atacora         Matéri     Tchianhoun-Cossi (Tehan)  10.820495
# 68     Atacora     Natitingou                   Kotapounga  10.255919
# 69     Atacora     Natitingou                       Kouaba  10.249991
# 70     Atacora     Natitingou                     Koundata  10.283333
# 71     Atacora     Natitingou                 Natitingou I  10.312910
# 72     Atacora     Natitingou                Natitingou II  10.300000
# 73     Atacora     Natitingou               Natitingou III  10.291243
# 74     Atacora     Natitingou  Natitingou IV (Péporiyakou)  10.255919
# 75     Atacora     Natitingou                        Perma  10.113984
# 76     Atacora     Natitingou              Tchoumi-Tchoumi  10.069080
# 77     Atacora        Péhunco                    Gnémasson  10.307800
# 78     Atacora        Péhunco                      Péhunco  10.228333
# 79     Atacora        Péhunco                        Tobré  10.200000
# 80     Atacora      Tanguiéta                     Cotiakou  10.592016
# 81     Atacora      Tanguiéta                    N'Dahonta  10.957200
# 82     Atacora      Tanguiéta                      Taiakou  10.550000
# 83     Atacora      Tanguiéta                    Tanguiéta  10.616667
# 84     Atacora      Tanguiéta                     Tanongou  10.957405
# 85     Atacora   Toucountouna                      Kouarfa  10.483333
# 86     Atacora   Toucountouna                     Tampégré  10.480000
# 87     Atacora   Toucountouna                 Toucountouna  10.498611
# 88  Atlantique  Abomey-Calavi                Abomey-Calavi   6.450000
# 89  Atlantique  Abomey-Calavi                     Akassato   6.507371
# 90  Atlantique  Abomey-Calavi                   Glo-Djigbé   6.506988
# 91  Atlantique  Abomey-Calavi                      Godomey   6.550000
# 92  Atlantique  Abomey-Calavi                        Hévié   6.416667
# 93  Atlantique  Abomey-Calavi                     Kpanroun   6.509167
# 94  Atlantique  Abomey-Calavi                        Ouédo   6.452429
# 95  Atlantique  Abomey-Calavi                        Togba   6.465136
# 96  Atlantique  Abomey-Calavi                       Zinvié   6.616667
# 97  Atlantique         Allada                      Agbanou   6.683333
# 98  Atlantique         Allada                Ahouannonzoun   6.662220
# 99  Atlantique         Allada                       Allada   6.664463
#
#     Longitude
# 0    2.439285
# 1    2.539781
# 2    2.471542
# 3    2.299982
# 4    2.283333
# 5    2.320930
# 6    2.404817
# 7    2.491331
# 8    2.466952
# 9    2.383056
# 10   2.724489
# 11   2.833333
# 12   2.846491
# 13   2.850000
# 14   2.784205
# 15   2.971111
# 16   3.041346
# 17   3.151615
# 18   2.855833
# 19   2.936944
# 20   2.935351
# 21   2.955860
# 22   2.903865
# 23   3.070278
# 24   2.733333
# 25   2.759722
# 26   3.221916
# 27   3.105848
# 28   3.183333
# 29   3.033837
# 30   2.924462
# 31   3.477609
# 32   3.227240
# 33   3.383333
# 34   3.270921
# 35   3.289804
# 36   3.585066
# 37   3.488976
# 38   2.533333
# 39   3.694444
# 40   3.428383
# 41   1.100000
# 42   0.988617
# 43   0.997778
# 44   1.200833
# 45   1.110598
# 46   1.116341
# 47   1.046276
# 48   0.999722
# 49   0.789002
# 50   0.947664
# 51   0.988611
# 52   2.072648
# 53   1.947866
# 54   2.109444
# 55   1.928367
# 56   1.526915
# 57   1.466667
# 58   1.683333
# 59   1.728334
# 60   1.691380
# 61   1.652740
# 62   1.140556
# 63   0.918611
# 64   0.994018
# 65   1.033333
# 66   1.033333
# 67   1.070249
# 68   1.381341
# 69   1.229559
# 70   1.333333
# 71   1.388616
# 72   1.385000
# 73   1.381837
# 74   1.381341
# 75   1.441053
# 76   1.403530
# 77   2.037855
# 78   2.001944
# 79   2.133333
# 80   1.303817
# 81   1.510200
# 82   1.200000
# 83   1.266667
# 84   1.409168
# 85   1.516667
# 86   1.450000
# 87   1.375556
# 88   2.350000
# 89   2.365643
# 90   2.331544
# 91   2.366667
# 92   2.250000
# 93   2.327778
# 94   2.267099
# 95   2.304864
# 96   2.350000
# 97   2.066667
# 98   2.119720
# 99   2.159760

# %%
print('The table dataframe has {} departments {} boroughs and {} neighborhoods.'.format(
        len(geo_coord_df['Department'].unique()), len(geo_coord_df['Region'].unique()),
        geo_coord_df.shape[0])
     )
# Out:
# The table dataframe has 3 departments 17 boroughs and 100 neighborhoods.

# %%
geo_coord_df['Department'].unique()
# Out:
# array(['Alibori', 'Atacora', 'Atlantique'], dtype=object)

# %% [markdown]
# <h1 align=center><font size = 5>Segmenting and Clustering Neighborhoods of a region in the northern part of the country</font></h1>

# %% [markdown]
# Let's explore the region of Banikoara in the department of Alibori which is located in the north of Benin

# %%
banikoara_df = geo_coord_df[geo_coord_df['Region'] == "Banikoara"].reset_index(drop=True)
banikoara_df
# Out:
#   Department     Region Neighborhood   Latitude  Longitude
# 0    Alibori  Banikoara    Banikoara  11.293970   2.439285
# 1    Alibori  Banikoara     Founougo  11.465990   2.539781
# 2    Alibori  Banikoara     Gomparou  11.328576   2.471542
# 3    Alibori  Banikoara      Goumori  11.178435   2.299982
# 4    Alibori  Banikoara        Kokey  11.183333   2.283333
# 5    Alibori  Banikoara    Kokiborou  11.202332   2.320930
# 6    Alibori  Banikoara        Ounet  11.227149   2.404817
# 7    Alibori  Banikoara   Sompérékou  11.322743   2.491331
# 8    Alibori  Banikoara       Soroko  11.327791   2.466952
# 9    Alibori  Banikoara        Toura  11.243611   2.383056

# %%
address = 'Banikoara, Benin'

geolocator = Nominatim(user_agent="ba_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Banikoara are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Banikoara are 11.32595885, 2.47303133750907.

# %%
# create map of Banikoara using latitude and longitude values
map_banikoara = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(banikoara_df['Latitude'], banikoara_df['Longitude'], banikoara_df['Region']
                                           , banikoara_df['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_banikoara)  
    
map_banikoara
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Define Foursquare Credentials and Version

# %%
# @hidden_cell
CLIENT_ID = 'NBFU034EIQA1KZN1031VY3KNP0ZWRDPTZTER3SJDAEAAN1GZ' # your Foursquare ID
CLIENT_SECRET = 'L402VNMJWLJHRI1DZBGORHSCORX4PRN3E3O0YXAMJUPSFSQZ' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %%
#Get the neighborhood's name.

banikoara_df.loc[0, 'Neighborhood']
# Out:
# 'Banikoara'

# %%
#Get the neighborhood's latitude and longitude values.

neighborhood_latitude = banikoara_df.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = banikoara_df.loc[0, 'Longitude'] # neighborhood longitude value

neighborhood_name = banikoara_df.loc[0, 'Neighborhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of Banikoara are 11.29397, 2.439285.

# %% [markdown]
# #### Now, let's get the top 100 venues that are in Banikoara within a radius of 50000 meters.

# %% [markdown]
# The choice of such big radius has been conditioned by the scarcity of data returned from Foursquare API. In fact, after many trials with small meters of radius, the radius of 50000 has given some consistent data with some inaccuracy due to interference with other regions. However we have approached this in our analysis

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API

radius = 50000 # define radius

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=NBFU034EIQA1KZN1031VY3KNP0ZWRDPTZTER3SJDAEAAN1GZ&client_secret=L402VNMJWLJHRI1DZBGORHSCORX4PRN3E3O0YXAMJUPSFSQZ&v=20180605&ll=11.29397,2.439285&radius=50000&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c9e00044c1f672903828ee1'},
#  'response': {'headerLocation': 'Current map view',
#   'headerFullLocation': 'Current map view',
#   'headerLocationGranularity': 'unknown',
#   'totalResults': 4,
#   'suggestedBounds': {'ne': {'lat': 11.74397045000045,
#     'lng': 2.897314870077757},
#    'sw': {'lat': 10.84396954999955, 'lng': 1.981255129922243}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5c20cb71bfc6d0002c78907d',
#        'name': 'Marché Central De Banikoara',
#        'location': {'lat': 11.295302,
#         'lng': 2.4309196,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 11.295302,
#           'lng': 2.4309196}],
#         'distance': 925,
#         'cc': 'BJ',
#         'city': 'Banikoara',
#         'state': 'Alibori',
#         'country': 'Bénin',
#         'formattedAddress': ['Banikoara', 'Bénin']},
#        'categories': [{'id': '50be8ee891d4fa8dcc7199a7',
#          'name': 'Market',
#          'pluralName': 'Markets',
#          'shortName': 'Market',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/market_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5c20cb71bfc6d0002c78907d-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5468d397498e43930e577e5b',
#        'name': 'Mercearia Costa e Silva',
#        'location': {'address': 'Avenida Sao Jorge Beco Santa Terezinha',
#         'crossStreet': 'São Geraldo',
#         'lat': 11.0487060546875,
#         'lng': 2.393841028213501,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 11.0487060546875,
#           'lng': 2.393841028213501}],
#         'distance': 27749,
#         'postalCode': '69053256',
#         'cc': 'BJ',
#         'city': 'Manaus',
#         'state': 'amazonas',
#         'country': 'Bénin',
#         'formattedAddress': ['Avenida Sao Jorge Beco Santa Terezinha (São Geraldo)',
#          'Manaus 69053256',
#          'Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d1f9941735',
#          'name': 'Food & Drink Shop',
#          'pluralName': 'Food & Drink Shops',
#          'shortName': 'Food & Drink',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/foodanddrink_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5468d397498e43930e577e5b-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56b201d9498e3415f8776517',
#        'name': 'Бирина',
#        'location': {'address': 'Богдана Хмельницький, 81',
#         'lat': 11.616608,
#         'lng': 2.456364,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 11.616608,
#           'lng': 2.456364}],
#         'distance': 35963,
#         'cc': 'BJ',
#         'city': 'Рубежное',
#         'country': 'Bénin',
#         'formattedAddress': ['Богдана Хмельницький, 81', 'Рубежное', 'Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d1f9941735',
#          'name': 'Food & Drink Shop',
#          'pluralName': 'Food & Drink Shops',
#          'shortName': 'Food & Drink',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/foodanddrink_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56b201d9498e3415f8776517-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56f6df9b498ed7b35d20b86f',
#        'name': 'Dikmen Caddesi',
#        'location': {'lat': 11.362971,
#         'lng': 2.0829225,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 11.362971,
#           'lng': 2.0829225}],
#         'distance': 39648,
#         'cc': 'BJ',
#         'country': 'Bénin',
#         'formattedAddress': ['Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56f6df9b498ed7b35d20b86f-3'}]}]}}

# %%
# function that extracts the category of the venue

def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
# Here we select the appropriate venue with regard to our region from the result of our querry 

venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                           name         categories        lat       lng
# 0  Marché Central De Banikoara             Market  11.295302  2.430920
# 1      Mercearia Costa e Silva  Food & Drink Shop  11.048706  2.393841
# 2                       Бирина  Food & Drink Shop  11.616608  2.456364
# 3               Dikmen Caddesi              Plaza  11.362971  2.082923

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 4 venues were returned by Foursquare.

# %%
# Function that returns only relevant information about the nearbyvenues of our chosen neighborhood
def getNearbyVenues(names, latitudes, longitudes, radius=50000):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
banikoara_venues = getNearbyVenues(names=banikoara_df['Neighborhood'],
                                   latitudes=banikoara_df['Latitude'],
                                   longitudes=banikoara_df['Longitude']
                                  )
# Out:
# Banikoara
# Founougo
# Gomparou
# Goumori
# Kokey
# Kokiborou
# Ounet
# Sompérékou
# Soroko
# Toura

# %%
print(banikoara_venues.shape)
banikoara_venues.head()
# Out:
# (52, 7)
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0    Banikoara               11.29397                2.439285
# 1    Banikoara               11.29397                2.439285
# 2    Banikoara               11.29397                2.439285
# 3    Banikoara               11.29397                2.439285
# 4     Founougo               11.46599                2.539781
#
#                          Venue  Venue Latitude  Venue Longitude  \
# 0  Marché Central De Banikoara       11.295302         2.430920
# 1      Mercearia Costa e Silva       11.048706         2.393841
# 2                       Бирина       11.616608         2.456364
# 3               Dikmen Caddesi       11.362971         2.082923
# 4                       Бирина       11.616608         2.456364
#
#       Venue Category
# 0             Market
# 1  Food & Drink Shop
# 2  Food & Drink Shop
# 3              Plaza
# 4  Food & Drink Shop

# %%
#Let's check how many venues were returned for each neighborhood

banikoara_venues.groupby('Neighborhood').count()
# Out:
#               Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# Banikoara                         4                       4      4
# Founougo                          6                       6      6
# Gomparou                          5                       5      5
# Goumori                           3                       3      3
# Kokey                             6                       6      6
# Kokiborou                         7                       7      7
# Ounet                             6                       6      6
# Sompérékou                        4                       4      4
# Soroko                            5                       5      5
# Toura                             6                       6      6
#
#               Venue Latitude  Venue Longitude  Venue Category
# Neighborhood
# Banikoara                  4                4               4
# Founougo                   6                6               6
# Gomparou                   5                5               5
# Goumori                    3                3               3
# Kokey                      6                6               6
# Kokiborou                  7                7               7
# Ounet                      6                6               6
# Sompérékou                 4                4               4
# Soroko                     5                5               5
# Toura                      6                6               6

# %%
print('There are {} uniques categories.'.format(len(banikoara_venues['Venue Category'].unique())))
# Out:
# There are 9 uniques categories.

# %% [markdown]
# ## Analyze Each Neighborhood

# %%
# one hot encoding
banikoara_onehot = pd.get_dummies(banikoara_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
banikoara_onehot['Neighborhood'] = banikoara_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [banikoara_onehot.columns[-1]] + list(banikoara_onehot.columns[:-1])
banikoara_onehot = banikoara_onehot[fixed_columns]

banikoara_onehot.head()
# Out:
#   Neighborhood  Botanical Garden  Breakfast Spot  Bus Stop  Café  \
# 0    Banikoara                 0               0         0     0
# 1    Banikoara                 0               0         0     0
# 2    Banikoara                 0               0         0     0
# 3    Banikoara                 0               0         0     0
# 4     Founougo                 0               0         0     0
#
#    Food & Drink Shop  Market  Plaza  Seafood Restaurant  Steakhouse
# 0                  0       1      0                   0           0
# 1                  1       0      0                   0           0
# 2                  1       0      0                   0           0
# 3                  0       0      1                   0           0
# 4                  1       0      0                   0           0

# %%
banikoara_onehot.shape
# Out:
# (52, 10)

# %%
#### Next, let's group rows by neighborhood and by taking the mean of the frequency of occurrence of each category# 

banikoara_grouped = banikoara_onehot.groupby('Neighborhood').mean().reset_index()
banikoara_grouped
# Out:
#   Neighborhood  Botanical Garden  Breakfast Spot  Bus Stop      Café  \
# 0    Banikoara          0.000000        0.000000  0.000000  0.000000
# 1     Founougo          0.166667        0.000000  0.166667  0.000000
# 2     Gomparou          0.000000        0.000000  0.200000  0.000000
# 3      Goumori          0.000000        0.333333  0.000000  0.000000
# 4        Kokey          0.000000        0.166667  0.000000  0.166667
# 5    Kokiborou          0.000000        0.142857  0.000000  0.142857
# 6        Ounet          0.000000        0.166667  0.000000  0.166667
# 7   Sompérékou          0.000000        0.000000  0.000000  0.000000
# 8       Soroko          0.000000        0.000000  0.200000  0.000000
# 9        Toura          0.000000        0.166667  0.000000  0.000000
#
#    Food & Drink Shop    Market     Plaza  Seafood Restaurant  Steakhouse
# 0           0.500000  0.250000  0.250000            0.000000    0.000000
# 1           0.333333  0.166667  0.000000            0.166667    0.000000
# 2           0.400000  0.200000  0.200000            0.000000    0.000000
# 3           0.000000  0.000000  0.333333            0.000000    0.333333
# 4           0.166667  0.166667  0.166667            0.000000    0.166667
# 5           0.285714  0.142857  0.142857            0.000000    0.142857
# 6           0.333333  0.166667  0.166667            0.000000    0.000000
# 7           0.500000  0.250000  0.250000            0.000000    0.000000
# 8           0.400000  0.200000  0.200000            0.000000    0.000000
# 9           0.333333  0.166667  0.166667            0.000000    0.166667

# %%
banikoara_grouped.shape
# Out:
# (10, 10)

# %%
##### Let's print each neighborhood along with the top 5 most common venues

num_top_venues = 5

for hood in banikoara_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = banikoara_grouped[banikoara_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Banikoara----
#                venue  freq
# 0  Food & Drink Shop  0.50
# 1             Market  0.25
# 2              Plaza  0.25
# 3   Botanical Garden  0.00
# 4     Breakfast Spot  0.00
#
#
# ----Founougo----
#                 venue  freq
# 0   Food & Drink Shop  0.33
# 1    Botanical Garden  0.17
# 2            Bus Stop  0.17
# 3              Market  0.17
# 4  Seafood Restaurant  0.17
#
#
# ----Gomparou----
#                venue  freq
# 0  Food & Drink Shop   0.4
# 1           Bus Stop   0.2
# 2             Market   0.2
# 3              Plaza   0.2
# 4   Botanical Garden   0.0
#
#
# ----Goumori----
#               venue  freq
# 0    Breakfast Spot  0.33
# 1             Plaza  0.33
# 2        Steakhouse  0.33
# 3  Botanical Garden  0.00
# 4          Bus Stop  0.00
#
#
# ----Kokey----
#                venue  freq
# 0     Breakfast Spot  0.17
# 1               Café  0.17
# 2  Food & Drink Shop  0.17
# 3             Market  0.17
# 4              Plaza  0.17
#
#
# ----Kokiborou----
#                venue  freq
# 0  Food & Drink Shop  0.29
# 1     Breakfast Spot  0.14
# 2               Café  0.14
# 3             Market  0.14
# 4              Plaza  0.14
#
#
# ----Ounet----
#                venue  freq
# 0  Food & Drink Shop  0.33
# 1     Breakfast Spot  0.17
# 2               Café  0.17
# 3             Market  0.17
# 4              Plaza  0.17
#
#
# ----Sompérékou----
#                venue  freq
# 0  Food & Drink Shop  0.50
# 1             Market  0.25
# 2              Plaza  0.25
# 3   Botanical Garden  0.00
# 4     Breakfast Spot  0.00
#
#
# ----Soroko----
#                venue  freq
# 0  Food & Drink Shop   0.4
# 1           Bus Stop   0.2
# 2             Market   0.2
# 3              Plaza   0.2
# 4   Botanical Garden   0.0
#
#
# ----Toura----
#                venue  freq
# 0  Food & Drink Shop  0.33
# 1     Breakfast Spot  0.17
# 2             Market  0.17
# 3              Plaza  0.17
# 4         Steakhouse  0.17

# %%
# A function to sort the venues in descending order.

def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
#Now let's create the new dataframe and display the top 10 venues for each neighborhood.

num_top_venues = 9

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = banikoara_grouped['Neighborhood']

for ind in np.arange(banikoara_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(banikoara_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#   Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0    Banikoara     Food & Drink Shop                 Plaza
# 1     Founougo     Food & Drink Shop    Seafood Restaurant
# 2     Gomparou     Food & Drink Shop                 Plaza
# 3      Goumori            Steakhouse                 Plaza
# 4        Kokey            Steakhouse                 Plaza
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0                Market            Steakhouse    Seafood Restaurant
# 1                Market              Bus Stop      Botanical Garden
# 2                Market              Bus Stop            Steakhouse
# 3        Breakfast Spot    Seafood Restaurant                Market
# 4                Market     Food & Drink Shop                  Café
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0                  Café              Bus Stop        Breakfast Spot
# 1            Steakhouse                 Plaza                  Café
# 2    Seafood Restaurant                  Café        Breakfast Spot
# 3     Food & Drink Shop                  Café              Bus Stop
# 4        Breakfast Spot    Seafood Restaurant              Bus Stop
#
#   9th Most Common Venue
# 0      Botanical Garden
# 1        Breakfast Spot
# 2      Botanical Garden
# 3      Botanical Garden
# 4      Botanical Garden

# %% [markdown]
# ## Cluster Neighborhoods

# %% [markdown]
# Run *k*-means to cluster the neighborhood into 2 clusters.

# %%
# set number of clusters
kclusters = 2

banikoara_grouped_clustering = banikoara_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(banikoara_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([1, 1, 1, 0, 0, 0, 0, 1, 1, 0], dtype=int32)

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

banikoara_merged = banikoara_df

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
banikoara_merged = banikoara_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

banikoara_merged.head() # check the last columns!
# Out:
#   Department     Region Neighborhood   Latitude  Longitude  Cluster Labels  \
# 0    Alibori  Banikoara    Banikoara  11.293970   2.439285               1
# 1    Alibori  Banikoara     Founougo  11.465990   2.539781               1
# 2    Alibori  Banikoara     Gomparou  11.328576   2.471542               1
# 3    Alibori  Banikoara      Goumori  11.178435   2.299982               0
# 4    Alibori  Banikoara        Kokey  11.183333   2.283333               0
#
#   1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0     Food & Drink Shop                 Plaza                Market
# 1     Food & Drink Shop    Seafood Restaurant                Market
# 2     Food & Drink Shop                 Plaza                Market
# 3            Steakhouse                 Plaza        Breakfast Spot
# 4            Steakhouse                 Plaza                Market
#
#   4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 0            Steakhouse    Seafood Restaurant                  Café
# 1              Bus Stop      Botanical Garden            Steakhouse
# 2              Bus Stop            Steakhouse    Seafood Restaurant
# 3    Seafood Restaurant                Market     Food & Drink Shop
# 4     Food & Drink Shop                  Café        Breakfast Spot
#
#   7th Most Common Venue 8th Most Common Venue 9th Most Common Venue
# 0              Bus Stop        Breakfast Spot      Botanical Garden
# 1                 Plaza                  Café        Breakfast Spot
# 2                  Café        Breakfast Spot      Botanical Garden
# 3                  Café              Bus Stop      Botanical Garden
# 4    Seafood Restaurant              Bus Stop      Botanical Garden

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(banikoara_merged['Latitude'], banikoara_merged['Longitude'], banikoara_merged['Neighborhood'], banikoara_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
banikoara_merged.loc[banikoara_merged['Cluster Labels'] == 0, banikoara_merged.columns[[2] + list(range(5, 9))]]
# Out:
#   Neighborhood  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 3      Goumori               0            Steakhouse                 Plaza
# 4        Kokey               0            Steakhouse                 Plaza
# 5    Kokiborou               0     Food & Drink Shop            Steakhouse
# 6        Ounet               0     Food & Drink Shop                 Plaza
# 9        Toura               0     Food & Drink Shop            Steakhouse
#
#   3rd Most Common Venue
# 3        Breakfast Spot
# 4                Market
# 5                 Plaza
# 6                Market
# 9                 Plaza

# %%
banikoara_merged.loc[banikoara_merged['Cluster Labels'] == 1, banikoara_merged.columns[[2] + list(range(5, 9))]]
# Out:
#   Neighborhood  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0    Banikoara               1     Food & Drink Shop                 Plaza
# 1     Founougo               1     Food & Drink Shop    Seafood Restaurant
# 2     Gomparou               1     Food & Drink Shop                 Plaza
# 7   Sompérékou               1     Food & Drink Shop                 Plaza
# 8       Soroko               1     Food & Drink Shop                 Plaza
#
#   3rd Most Common Venue
# 0                Market
# 1                Market
# 2                Market
# 7                Market
# 8                Market

# %% [markdown]
# With less quality data we can infer here that in Banikoara a region situtated in the northern part of Benin that the 3
# first common venue of interest are : Food & Drink Shop, Plaza and Market The result is quite understandable because this part of the country abunds of farming land as mentioned in the introduction due to the remoted character of the region. And moreover for clarification this venues are full of small business that helps families survive and covers the daily business.

# %% [markdown]
# Let's now explore the region of Abomey-Calavi in the department of Atlantique at the south of the country

# %% [markdown]
# <h1 align=center><font size = 5>Segmenting and Clustering Neighborhoods of a region in the southern part of the country</font></h1>

# %%
AbomeyCalavi_df = geo_coord_df[geo_coord_df['Region'] == "Abomey-Calavi"].reset_index(drop=True)
AbomeyCalavi_df
# Out:
#    Department         Region   Neighborhood  Latitude  Longitude
# 0  Atlantique  Abomey-Calavi  Abomey-Calavi  6.450000   2.350000
# 1  Atlantique  Abomey-Calavi       Akassato  6.507371   2.365643
# 2  Atlantique  Abomey-Calavi     Glo-Djigbé  6.506988   2.331544
# 3  Atlantique  Abomey-Calavi        Godomey  6.550000   2.366667
# 4  Atlantique  Abomey-Calavi          Hévié  6.416667   2.250000
# 5  Atlantique  Abomey-Calavi       Kpanroun  6.509167   2.327778
# 6  Atlantique  Abomey-Calavi          Ouédo  6.452429   2.267099
# 7  Atlantique  Abomey-Calavi          Togba  6.465136   2.304864
# 8  Atlantique  Abomey-Calavi         Zinvié  6.616667   2.350000

# %%
address = 'Abomey-Calavi, Benin'

geolocator = Nominatim(user_agent="ab_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Abomey-Calavi are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Abomey-Calavi are 6.4153695, 2.30622836336264.

# %%
# create map of New York using latitude and longitude values
map_AbomeyCalavi = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(AbomeyCalavi_df['Latitude'], AbomeyCalavi_df['Longitude'], 
                                           AbomeyCalavi_df['Region'], AbomeyCalavi_df['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_AbomeyCalavi)  
    
map_AbomeyCalavi
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Get the neighborhood's name.
AbomeyCalavi_df.loc[0, 'Neighborhood']
# Out:
# 'Abomey-Calavi'

# %%
neighborhood_latitude = AbomeyCalavi_df.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = AbomeyCalavi_df.loc[0, 'Longitude'] # neighborhood longitude value

neighborhood_name = AbomeyCalavi_df.loc[0, 'Neighborhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of Abomey-Calavi are 6.45, 2.35.

# %% [markdown]
# #### Now, let's get the top 100 venues that are in Abomey-Calavi within a radius of 50000 meters.

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
#2000
radius = 50000 # define radius

url2 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url2
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=NBFU034EIQA1KZN1031VY3KNP0ZWRDPTZTER3SJDAEAAN1GZ&client_secret=L402VNMJWLJHRI1DZBGORHSCORX4PRN3E3O0YXAMJUPSFSQZ&v=20180605&ll=6.45,2.35&radius=50000&limit=100'

# %%
results2 = requests.get(url2).json()
results2
# Out:
# {'meta': {'code': 200, 'requestId': '5c9e00086a607153469ad335'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Current map view',
#   'headerFullLocation': 'Current map view',
#   'headerLocationGranularity': 'unknown',
#   'totalResults': 37,
#   'suggestedBounds': {'ne': {'lat': 6.900000450000451,
#     'lng': 2.802021423138588},
#    'sw': {'lat': 5.99999954999955, 'lng': 1.8979785768614121}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d984cacc19fb60c4e40ab65',
#        'name': 'Eldorado Beach Club',
#        'location': {'address': 'Rue 1764',
#         'lat': 6.3573960448784,
#         'lng': 2.4636912230545502,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.3573960448784,
#           'lng': 2.4636912230545502}],
#         'distance': 16261,
#         'postalCode': '229',
#         'cc': 'BJ',
#         'city': 'Cotonou',
#         'state': 'Lit.',
#         'country': 'Bénin',
#         'formattedAddress': ['Rue 1764', 'Cotonou 229', 'Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d1e2941735',
#          'name': 'Beach',
#          'pluralName': 'Beaches',
#          'shortName': 'Beach',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/beach_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d984cacc19fb60c4e40ab65-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5109758ee4b08c09c899d430',
#        'name': 'Code Bar',
#        'location': {'lat': 6.351882344800396,
#         'lng': 2.3864491502540415,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.351882344800396,
#           'lng': 2.3864491502540415}],
#         'distance': 11642,
#         'cc': 'BJ',
#         'city': 'Cotonou',
#         'state': 'Lit',
#         'country': 'Bénin',
#         'formattedAddress': ['Cotonou', 'Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d121941735',
#          'name': 'Lounge',
#          'pluralName': 'Lounges',
#          'shortName': 'Lounge',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5109758ee4b08c09c899d430-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f4b3e74e4b0ecc815a20b6f',
#        'name': 'La Roche',
#        'location': {'address': 'info@larochebenin.com',
#         'lat': 6.362236032745331,
#         'lng': 2.4462224532404298,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.362236032745331,
#           'lng': 2.4462224532404298}],
#         'distance': 14448,
#         'postalCode': '01 BP 2525',
#         'cc': 'BJ',
#         'city': 'Cotonou',
#         'state': 'Littoral',
#         'country': 'Bénin',
#         'formattedAddress': ['info@larochebenin.com',
#          'Cotonou 01 BP 2525',
#          'Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d112951735',
#          'name': 'Hardware Store',
#          'pluralName': 'Hardware Stores',
#          'shortName': 'Hardware',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f4b3e74e4b0ecc815a20b6f-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51a124af498e9de8135cc712',
#        'name': "L'Impala",
#        'location': {'address': 'Rue du Cncb',
#         'lat': 6.35305513203476,
#         'lng': 2.419738426982096,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.35305513203476,
#           'lng': 2.419738426982096}],
#         'distance': 13265,
#         'postalCode': '99000',
#         'cc': 'BJ',
#         'neighborhood': 'Zone Residentielle',
#         'country': 'Bénin',
#         'formattedAddress': ['Rue du Cncb', '99000', 'Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51a124af498e9de8135cc712-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e667ad745dde0f9e206c091',
#        'name': 'Bangkok Terrasse',
#        'location': {'address': 'Rue 449',
#         'crossStreet': 'Entre rue 235 et rue 234',
#         'lat': 6.353995672037863,
#         'lng': 2.417403056955195,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.353995672037863,
#           'lng': 2.417403056955195}],
#         'distance': 13031,
#         'cc': 'BJ',
#         'city': 'Cotonou',
#         'state': 'Littoral',
#         'country': 'Bénin',
#         'formattedAddress': ['Rue 449 (Entre rue 235 et rue 234)',
#          'Cotonou',
#          'Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d149941735',
#          'name': 'Thai Restaurant',
#          'pluralName': 'Thai Restaurants',
#          'shortName': 'Thai',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e667ad745dde0f9e206c091-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4db3bc7290a0843f29648b57',
#        'name': 'Mojito',
#        'location': {'address': 'Avenue Clozel Cotonou, Benin',
#         'crossStreet': "Entre Baguette d'or et Western Union",
#         'lat': 6.35458460154133,
#         'lng': 2.4364844454600294,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.35458460154133,
#           'lng': 2.4364844454600294}],
#         'distance': 14295,
#         'cc': 'BJ',
#         'city': 'Cotonou',
#         'state': 'Littoral',
#         'country': 'Bénin',
#         'formattedAddress': ["Avenue Clozel Cotonou, Benin (Entre Baguette d'or et Western Union)",
#          'Cotonou',
#          'Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d1e5931735',
#          'name': 'Music Venue',
#          'pluralName': 'Music Venues',
#          'shortName': 'Music Venue',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4db3bc7290a0843f29648b57-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '584eaace4ca49b33ed2769b2',
#        'name': 'Ci Gusta',
#        'location': {'lat': 6.355329,
#         'lng': 2.417331,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.355329,
#           'lng': 2.417331}],
#         'distance': 12905,
#         'cc': 'BJ',
#         'country': 'Bénin',
#         'formattedAddress': ['Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-584eaace4ca49b33ed2769b2-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5344f9f7498e245750339c26',
#        'name': 'La Galette à Sucre',
#        'location': {'address': 'Face ministère des finances',
#         'lat': 6.353679469564765,
#         'lng': 2.3972566759262666,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.353679469564765,
#           'lng': 2.3972566759262666}],
#         'distance': 11928,
#         'cc': 'BJ',
#         'city': 'Cotonou',
#         'state': 'Littoral',
#         'country': 'Bénin',
#         'formattedAddress': ['Face ministère des finances',
#          'Cotonou',
#          'Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5344f9f7498e245750339c26-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e05c989b61c60b0453a1de4',
#        'name': 'Erevan',
#        'location': {'lat': 6.3492734009468625,
#         'lng': 2.3865417555647004,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.3492734009468625,
#           'lng': 2.3865417555647004}],
#         'distance': 11919,
#         'cc': 'BJ',
#         'city': 'Cotonou',
#         'state': 'Littoral',
#         'country': 'Bénin',
#         'formattedAddress': ['Cotonou', 'Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e05c989b61c60b0453a1de4-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dda44c07d8b32266431ef89',
#        'name': 'Festival Des Glaces',
#        'location': {'address': 'Bld Steinmetz',
#         'crossStreet': 'Entre rue 116 et rue 117',
#         'lat': 6.3650250336247005,
#         'lng': 2.4312709177447727,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.3650250336247005,
#           'lng': 2.4312709177447727}],
#         'distance': 13050,
#         'cc': 'BJ',
#         'city': 'Cotonou',
#         'state': 'Littoral',
#         'country': 'Bénin',
#         'formattedAddress': ['Bld Steinmetz (Entre rue 116 et rue 117)',
#          'Cotonou',
#          'Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dda44c07d8b32266431ef89-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51a4b2d0498e4690475adce1',
#        'name': 'Best Western Plus',
#        'location': {'lat': 6.353737272013232,
#         'lng': 2.38829735782419,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.353737272013232,
#           'lng': 2.38829735782419}],
#         'distance': 11522,
#         'cc': 'BJ',
#         'country': 'Bénin',
#         'formattedAddress': ['Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d12f951735',
#          'name': 'Resort',
#          'pluralName': 'Resorts',
#          'shortName': 'Resort',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/resort_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51a4b2d0498e4690475adce1-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d9c71a0c540236aa241784b',
#        'name': 'Le Livingstone',
#        'location': {'address': 'Piste Amalco',
#         'crossStreet': 'Rue 964',
#         'lat': 6.356746464685261,
#         'lng': 2.3941087643794976,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.356746464685261,
#           'lng': 2.3941087643794976}],
#         'distance': 11470,
#         'cc': 'BJ',
#         'city': 'Cotonou',
#         'state': 'Littoral',
#         'country': 'Bénin',
#         'formattedAddress': ['Piste Amalco (Rue 964)', 'Cotonou', 'Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d9c71a0c540236aa241784b-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f6d0318e4b0a4e20f38ca80',
#        'name': 'Pk 7 Zone Des Ambassades',
#        'location': {'address': 'Akpakpa PK7',
#         'lat': 6.366146732454145,
#         'lng': 2.49132896012783,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.366146732454145,
#           'lng': 2.49132896012783}],
#         'distance': 18208,
#         'cc': 'BJ',
#         'city': 'Cotonou',
#         'state': 'Littoral',
#         'country': 'Bénin',
#         'formattedAddress': ['Akpakpa PK7', 'Cotonou', 'Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f6d0318e4b0a4e20f38ca80-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4da3286a7ccc816e50d6767b',
#        'name': 'Hotel Du Lac',
#        'location': {'address': 'Rue 1885',
#         'lat': 6.358720215531096,
#         'lng': 2.4448614737676584,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.358720215531096,
#           'lng': 2.4448614737676584}],
#         'distance': 14607,
#         'postalCode': '228',
#         'cc': 'BJ',
#         'city': 'Cotonou',
#         'state': 'Littoral',
#         'country': 'Bénin',
#         'formattedAddress': ['Rue 1885', 'Cotonou 228', 'Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d1d5941735',
#          'name': 'Hotel Bar',
#          'pluralName': 'Hotel Bars',
#          'shortName': 'Hotel Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4da3286a7ccc816e50d6767b-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d97a2c2c19fb60cda3a9c65',
#        'name': 'Teranga',
#        'location': {'address': '8 BP 1181 Haie Vive',
#         'crossStreet': 'Rue 375',
#         'lat': 6.356824094745199,
#         'lng': 2.3911048722922574,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.356824094745199,
#           'lng': 2.3911048722922574}],
#         'distance': 11325,
#         'cc': 'BJ',
#         'city': 'Cotonou',
#         'state': 'Littoral',
#         'country': 'Bénin',
#         'formattedAddress': ['8 BP 1181 Haie Vive (Rue 375)',
#          'Cotonou',
#          'Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d115941735',
#          'name': 'Middle Eastern Restaurant',
#          'pluralName': 'Middle Eastern Restaurants',
#          'shortName': 'Middle Eastern',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d97a2c2c19fb60cda3a9c65-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54fafe83498e95a553fc5a68',
#        'name': 'Centre commercial & Hypermarché EREVAN',
#        'location': {'address': 'Boulevard de la Cen-Sad',
#         'lat': 6.349927572916672,
#         'lng': 2.3870823431693498,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.349927572916672,
#           'lng': 2.3870823431693498}],
#         'distance': 11871,
#         'postalCode': '01 B.P. 936',
#         'cc': 'BJ',
#         'city': 'Cotonou',
#         'state': 'Littoral',
#         'country': 'Bénin',
#         'formattedAddress': ['Boulevard de la Cen-Sad',
#          'Cotonou 01 B.P. 936',
#          'Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54fafe83498e95a553fc5a68-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e67c75b18a8bf0571c06330',
#        'name': 'Le Resto',
#        'location': {'address': 'Rue Amelco',
#         'lat': 6.356493026690624,
#         'lng': 2.397667821278077,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.356493026690624,
#           'lng': 2.397667821278077}],
#         'distance': 11668,
#         'cc': 'BJ',
#         'city': 'Cotonou',
#         'state': 'Littoral',
#         'country': 'Bénin',
#         'formattedAddress': ['Rue Amelco', 'Cotonou', 'Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d115941735',
#          'name': 'Middle Eastern Restaurant',
#          'pluralName': 'Middle Eastern Restaurants',
#          'shortName': 'Middle Eastern',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e67c75b18a8bf0571c06330-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50d96f0ee4b06651e7ebd9e6',
#        'name': 'Gbejromede',
#        'location': {'lat': 6.384440273282167,
#         'lng': 2.4171296628523784,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.384440273282167,
#           'lng': 2.4171296628523784}],
#         'distance': 10411,
#         'cc': 'BJ',
#         'country': 'Bénin',
#         'formattedAddress': ['Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50d96f0ee4b06651e7ebd9e6-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ce6eb0ab99754816e16f344',
#        'name': 'Maquis du Port',
#        'location': {'address': 'Boulevard de la Marina',
#         'lat': 6.351470042791563,
#         'lng': 2.433566171105044,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.351470042791563,
#           'lng': 2.433566171105044}],
#         'distance': 14344,
#         'cc': 'BJ',
#         'city': 'Cotonou',
#         'state': 'Littoral',
#         'country': 'Bénin',
#         'formattedAddress': ['Boulevard de la Marina', 'Cotonou', 'Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d1c8941735',
#          'name': 'African Restaurant',
#          'pluralName': 'African Restaurants',
#          'shortName': 'African',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/african_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ce6eb0ab99754816e16f344-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e620dbf1838ad3d0e9ca308',
#        'name': 'Benin Marina Hotel',
#        'location': {'address': '01 BP 1901',
#         'lat': 6.353046699999999,
#         'lng': 2.4358856,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.353046699999999,
#           'lng': 2.4358856}],
#         'distance': 14378,
#         'cc': 'BJ',
#         'city': 'Cotonou',
#         'state': 'Littoral',
#         'country': 'Bénin',
#         'formattedAddress': ['01 BP 1901', 'Cotonou', 'Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d12f951735',
#          'name': 'Resort',
#          'pluralName': 'Resorts',
#          'shortName': 'Resort',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/resort_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e620dbf1838ad3d0e9ca308-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dab5064a86e771ea7373e4d',
#        'name': 'Le Cordon Bleu',
#        'location': {'address': 'Hai Vive',
#         'lat': 6.356722562188486,
#         'lng': 2.3970010844740224,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.356722562188486,
#           'lng': 2.3970010844740224}],
#         'distance': 11612,
#         'cc': 'BJ',
#         'city': 'Cotonou',
#         'state': 'Littoral',
#         'country': 'Bénin',
#         'formattedAddress': ['Hai Vive', 'Cotonou', 'Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dab5064a86e771ea7373e4d-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ef3820e30f87cc516e9eaa4',
#        'name': 'Bistrot Japonais Daruma',
#        'location': {'address': 'Entre Piste Amelco et rue 374',
#         'crossStreet': 'Rue 964',
#         'lat': 6.356429571068937,
#         'lng': 2.392844259738922,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.356429571068937,
#           'lng': 2.392844259738922}],
#         'distance': 11443,
#         'cc': 'BJ',
#         'city': 'Cotonou',
#         'state': 'Lit.',
#         'country': 'Bénin',
#         'formattedAddress': ['Entre Piste Amelco et rue 374 (Rue 964)',
#          'Cotonou',
#          'Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ef3820e30f87cc516e9eaa4-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51e067b3498e5dc06e1f5bfb',
#        'name': 'Le Palais du Chawarma',
#        'location': {'address': 'Avenue Toffa 1er',
#         'crossStreet': 'Quartier Oussoumédé',
#         'lat': 6.479798,
#         'lng': 2.633258,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.479798,
#           'lng': 2.633258}],
#         'distance': 31506,
#         'cc': 'BJ',
#         'city': 'Porto Novo',
#         'state': 'Département de l’ Ouémé',
#         'country': 'Bénin',
#         'formattedAddress': ['Avenue Toffa 1er (Quartier Oussoumédé)',
#          'Porto Novo',
#          'Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51e067b3498e5dc06e1f5bfb-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58936526a19e903e16ff5c76',
#        'name': 'Golden Tulip Le Diplomate - Cotonou',
#        'location': {'address': 'N° 90 rue 12.017 - Boulevard de la Marina',
#         'lat': 6.349017110840986,
#         'lng': 2.4032462237919927,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.349017110840986,
#           'lng': 2.4032462237919927}],
#         'distance': 12691,
#         'postalCode': '01 BP 8379',
#         'cc': 'BJ',
#         'city': 'Cotonou',
#         'state': 'Littoral',
#         'country': 'Bénin',
#         'formattedAddress': ['N° 90 rue 12.017 - Boulevard de la Marina',
#          'Cotonou 01 BP 8379',
#          'Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58936526a19e903e16ff5c76-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dfb8fe462e19b42f1e4b2fd',
#        'name': 'Le Privé',
#        'location': {'address': 'Ave Clozel',
#         'crossStreet': 'Entre Rue 864B et Rue 866',
#         'lat': 6.356769914887114,
#         'lng': 2.4392614823710663,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.356769914887114,
#           'lng': 2.4392614823710663}],
#         'distance': 14325,
#         'cc': 'BJ',
#         'city': 'Cotonou',
#         'state': 'Littoral',
#         'country': 'Bénin',
#         'formattedAddress': ['Ave Clozel (Entre Rue 864B et Rue 866)',
#          'Cotonou',
#          'Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d122941735',
#          'name': 'Whisky Bar',
#          'pluralName': 'Whisky Bars',
#          'shortName': 'Whisky Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/whiskey_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dfb8fe462e19b42f1e4b2fd-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f7f2279e4b08fc03a0139aa',
#        'name': 'Azalaï Hotel de la Plage',
#        'location': {'lat': 6.351695052972152,
#         'lng': 2.435668740890041,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.351695052972152,
#           'lng': 2.435668740890041}],
#         'distance': 14476,
#         'cc': 'BJ',
#         'neighborhood': 'Quartier Ganhi',
#         'city': 'Cotonou',
#         'state': 'Littoral',
#         'country': 'Bénin',
#         'formattedAddress': ['Cotonou', 'Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f7f2279e4b08fc03a0139aa-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4da9e5d30cb6a89c62617c3b',
#        'name': 'VIP Lounge',
#        'location': {'lat': 6.35370755366868,
#         'lng': 2.384869487400702,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.35370755366868,
#           'lng': 2.384869487400702}],
#         'distance': 11392,
#         'cc': 'BJ',
#         'country': 'Bénin',
#         'formattedAddress': ['Bénin']},
#        'categories': [{'id': '4eb1bc533b7b2c5b1d4306cb',
#          'name': 'Airport Lounge',
#          'pluralName': 'Airport Lounges',
#          'shortName': 'Lounge',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4da9e5d30cb6a89c62617c3b-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4eb8d6238b81a81f91fb2b3d',
#        'name': 'Hotel Ibis',
#        'location': {'lat': 6.3492104322791425,
#         'lng': 2.4014749828040367,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.3492104322791425,
#           'lng': 2.4014749828040367}],
#         'distance': 12582,
#         'cc': 'BJ',
#         'city': 'Cotonou',
#         'state': 'Littoral',
#         'country': 'Bénin',
#         'formattedAddress': ['Cotonou', 'Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d12f951735',
#          'name': 'Resort',
#          'pluralName': 'Resorts',
#          'shortName': 'Resort',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/resort_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4eb8d6238b81a81f91fb2b3d-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e46c0eb62e148603b76dff4',
#        'name': 'Stade Mathieu Kerekou',
#        'location': {'lat': 6.386076977613844,
#         'lng': 2.3744037587302165,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.386076977613844,
#           'lng': 2.3744037587302165}],
#         'distance': 7610,
#         'cc': 'BJ',
#         'city': 'Cotonou',
#         'state': 'Littoral',
#         'country': 'Bénin',
#         'formattedAddress': ['Cotonou', 'Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d188941735',
#          'name': 'Soccer Stadium',
#          'pluralName': 'Soccer Stadiums',
#          'shortName': 'Soccer',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_soccer_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e46c0eb62e148603b76dff4-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53334487498ee518e58014dd',
#        'name': 'La Plancha',
#        'location': {'lat': 6.35659990524599,
#         'lng': 2.392231912355358,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.35659990524599,
#           'lng': 2.392231912355358}],
#         'distance': 11398,
#         'cc': 'BJ',
#         'city': 'Cotonou',
#         'state': 'Littoral',
#         'country': 'Bénin',
#         'formattedAddress': ['Cotonou', 'Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d1db931735',
#          'name': 'Tapas Restaurant',
#          'pluralName': 'Tapas Restaurants',
#          'shortName': 'Tapas',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53334487498ee518e58014dd-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f4b69d4e4b011fb788ed1d6',
#        'name': 'Le Roi du Shawarma',
#        'location': {'lat': 6.36126128606177,
#         'lng': 2.434897229425914,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.36126128606177,
#           'lng': 2.434897229425914}],
#         'distance': 13630,
#         'cc': 'BJ',
#         'country': 'Bénin',
#         'formattedAddress': ['Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f4b69d4e4b011fb788ed1d6-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e5d375cb61cc7d93845626f',
#        'name': 'Festival des Glaces',
#        'location': {'address': 'Rue 395 - Haie Vive',
#         'crossStreet': 'Quartier Cadjehoun',
#         'lat': 6.356817311636116,
#         'lng': 2.39959082273638,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.356817311636116,
#           'lng': 2.39959082273638}],
#         'distance': 11734,
#         'cc': 'BJ',
#         'city': 'Cotonou',
#         'state': 'Littoral',
#         'country': 'Bénin',
#         'formattedAddress': ['Rue 395 - Haie Vive (Quartier Cadjehoun)',
#          'Cotonou',
#          'Bénin']},
#        'categories': [{'id': '4d4b7105d754a06374d81259',
#          'name': 'Food',
#          'pluralName': 'Food',
#          'shortName': 'Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e5d375cb61cc7d93845626f-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e53b07c483b944199e0cd33',
#        'name': 'Malongo',
#        'location': {'lat': 6.349441997602504,
#         'lng': 2.386336937903934,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.349441997602504,
#           'lng': 2.386336937903934}],
#         'distance': 11893,
#         'cc': 'BJ',
#         'city': 'Cotonou',
#         'state': 'Littoral',
#         'country': 'Bénin',
#         'formattedAddress': ['Cotonou', 'Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e53b07c483b944199e0cd33-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fd9a672e4b0b011323ff1cb',
#        'name': "La Gerbe d'Or",
#        'location': {'address': 'Ganhi',
#         'lat': 6.355264809926915,
#         'lng': 2.4372622530588863,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.355264809926915,
#           'lng': 2.4372622530588863}],
#         'distance': 14296,
#         'cc': 'BJ',
#         'city': 'Cotonou',
#         'state': 'Littoral',
#         'country': 'Bénin',
#         'formattedAddress': ['Ganhi', 'Cotonou', 'Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fd9a672e4b0b011323ff1cb-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '524bf714498e2a31147497a4',
#        'name': 'Port Cotonou',
#        'location': {'lat': 6.376979725671893,
#         'lng': 2.4880817174995284,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.376979725671893,
#           'lng': 2.4880817174995284}],
#         'distance': 17303,
#         'cc': 'BJ',
#         'country': 'Bénin',
#         'formattedAddress': ['Bénin']},
#        'categories': [{'id': '4e74f6cabd41c4836eac4c31',
#          'name': 'Pier',
#          'pluralName': 'Piers',
#          'shortName': 'Piers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/ferry_pier_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-524bf714498e2a31147497a4-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51e56fa8498e3bbf10f907ca',
#        'name': 'La Championne',
#        'location': {'address': 'Boulevard Lagunaire',
#         'crossStreet': 'Face à la Diamond Bank',
#         'lat': 6.4821347901154684,
#         'lng': 2.610842906770526,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.4821347901154684,
#           'lng': 2.610842906770526}],
#         'distance': 29072,
#         'cc': 'BJ',
#         'city': 'Porto Novo',
#         'state': 'Département de l’ Ouémé',
#         'country': 'Bénin',
#         'formattedAddress': ['Boulevard Lagunaire (Face à la Diamond Bank)',
#          'Porto Novo',
#          'Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51e56fa8498e3bbf10f907ca-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '520d362111d22027ad9d80d1',
#        'name': 'Auberge De La Diaspora',
#        'location': {'lat': 6.325252099678863,
#         'lng': 2.092180124246285,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 6.325252099678863,
#           'lng': 2.092180124246285}],
#         'distance': 31723,
#         'cc': 'BJ',
#         'country': 'Bénin',
#         'formattedAddress': ['Bénin']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-520d362111d22027ad9d80d1-36'}]}]}}

# %%
AbomeyCalavi_venues = getNearbyVenues(names=AbomeyCalavi_df['Neighborhood'],
                                   latitudes=AbomeyCalavi_df['Latitude'],
                                   longitudes=AbomeyCalavi_df['Longitude']
                                  )
# Out:
# Abomey-Calavi
# Akassato
# Glo-Djigbé
# Godomey
# Hévié
# Kpanroun
# Ouédo
# Togba
# Zinvié

# %%
# Here we select the appropriate venue with regard to our region from the result of our querry 

venues = results2['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues
# Out:
#                                       name                 categories  \
# 0                      Eldorado Beach Club                      Beach
# 1                                 Code Bar                     Lounge
# 2                                 La Roche             Hardware Store
# 3                                 L'Impala                 Restaurant
# 4                         Bangkok Terrasse            Thai Restaurant
# 5                                   Mojito                Music Venue
# 6                                 Ci Gusta             Ice Cream Shop
# 7                       La Galette à Sucre                     Bakery
# 8                                   Erevan              Shopping Mall
# 9                      Festival Des Glaces               Dessert Shop
# 10                       Best Western Plus                     Resort
# 11                          Le Livingstone                Pizza Place
# 12                Pk 7 Zone Des Ambassades                      Plaza
# 13                            Hotel Du Lac                  Hotel Bar
# 14                                 Teranga  Middle Eastern Restaurant
# 15  Centre commercial & Hypermarché EREVAN              Shopping Mall
# 16                                Le Resto  Middle Eastern Restaurant
# 17                              Gbejromede                      Plaza
# 18                          Maquis du Port         African Restaurant
# 19                      Benin Marina Hotel                     Resort
# 20                          Le Cordon Bleu          French Restaurant
# 21                 Bistrot Japonais Daruma        Japanese Restaurant
# 22                   Le Palais du Chawarma       Fast Food Restaurant
# 23     Golden Tulip Le Diplomate - Cotonou                      Hotel
# 24                                Le Privé                 Whisky Bar
# 25                Azalaï Hotel de la Plage                      Hotel
# 26                              VIP Lounge             Airport Lounge
# 27                              Hotel Ibis                     Resort
# 28                   Stade Mathieu Kerekou             Soccer Stadium
# 29                              La Plancha           Tapas Restaurant
# 30                      Le Roi du Shawarma             Sandwich Place
# 31                     Festival des Glaces                       Food
# 32                                 Malongo                 Food Court
# 33                           La Gerbe d'Or                     Bakery
# 34                            Port Cotonou                       Pier
# 35                           La Championne              Shopping Mall
# 36                  Auberge De La Diaspora                      Hotel
#
#          lat       lng
# 0   6.357396  2.463691
# 1   6.351882  2.386449
# 2   6.362236  2.446222
# 3   6.353055  2.419738
# 4   6.353996  2.417403
# 5   6.354585  2.436484
# 6   6.355329  2.417331
# 7   6.353679  2.397257
# 8   6.349273  2.386542
# 9   6.365025  2.431271
# 10  6.353737  2.388297
# 11  6.356746  2.394109
# 12  6.366147  2.491329
# 13  6.358720  2.444861
# 14  6.356824  2.391105
# 15  6.349928  2.387082
# 16  6.356493  2.397668
# 17  6.384440  2.417130
# 18  6.351470  2.433566
# 19  6.353047  2.435886
# 20  6.356723  2.397001
# 21  6.356430  2.392844
# 22  6.479798  2.633258
# 23  6.349017  2.403246
# 24  6.356770  2.439261
# 25  6.351695  2.435669
# 26  6.353708  2.384869
# 27  6.349210  2.401475
# 28  6.386077  2.374404
# 29  6.356600  2.392232
# 30  6.361261  2.434897
# 31  6.356817  2.399591
# 32  6.349442  2.386337
# 33  6.355265  2.437262
# 34  6.376980  2.488082
# 35  6.482135  2.610843
# 36  6.325252  2.092180

# %%
print(AbomeyCalavi_venues.shape)
AbomeyCalavi_venues.head()
# Out:
# (332, 7)
#     Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Abomey-Calavi                   6.45                    2.35
# 1  Abomey-Calavi                   6.45                    2.35
# 2  Abomey-Calavi                   6.45                    2.35
# 3  Abomey-Calavi                   6.45                    2.35
# 4  Abomey-Calavi                   6.45                    2.35
#
#                  Venue  Venue Latitude  Venue Longitude   Venue Category
# 0  Eldorado Beach Club        6.357396         2.463691            Beach
# 1             Code Bar        6.351882         2.386449           Lounge
# 2             La Roche        6.362236         2.446222   Hardware Store
# 3             L'Impala        6.353055         2.419738       Restaurant
# 4     Bangkok Terrasse        6.353996         2.417403  Thai Restaurant

# %%
AbomeyCalavi_venues.groupby('Neighborhood').count()
# Out:
#                Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# Abomey-Calavi                     37                      37     37
# Akassato                          37                      37     37
# Glo-Djigbé                        37                      37     37
# Godomey                           37                      37     37
# Hévié                             36                      36     36
# Kpanroun                          37                      37     37
# Ouédo                             37                      37     37
# Togba                             37                      37     37
# Zinvié                            37                      37     37
#
#                Venue Latitude  Venue Longitude  Venue Category
# Neighborhood
# Abomey-Calavi              37               37              37
# Akassato                   37               37              37
# Glo-Djigbé                 37               37              37
# Godomey                    37               37              37
# Hévié                      36               36              36
# Kpanroun                   37               37              37
# Ouédo                      37               37              37
# Togba                      37               37              37
# Zinvié                     37               37              37

# %%
print('There are {} uniques categories.'.format(len(AbomeyCalavi_venues['Venue Category'].unique())))
# Out:
# There are 28 uniques categories.

# %% [markdown]
# ## Analyze Each Neighborhood

# %%
# one hot encoding
AbomeyCalavi_onehot = pd.get_dummies(AbomeyCalavi_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
AbomeyCalavi_onehot['Neighborhood'] = AbomeyCalavi_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [AbomeyCalavi_onehot.columns[-1]] + list(AbomeyCalavi_onehot.columns[:-1])
AbomeyCalavi_onehot = AbomeyCalavi_onehot[fixed_columns]

AbomeyCalavi_onehot.sample(frac= 0.7).head(10)
# Out:
#     Neighborhood  African Restaurant  Airport Lounge  Bakery  Beach  \
# 107   Glo-Djigbé                   0               0       1      0
# 89    Glo-Djigbé                   0               0       0      0
# 233        Ouédo                   0               0       0      0
# 251        Ouédo                   0               0       0      0
# 173        Hévié                   0               0       0      0
# 148        Hévié                   0               0       0      0
# 223        Ouédo                   0               0       0      0
# 50      Akassato                   0               0       0      0
# 104   Glo-Djigbé                   0               0       0      0
# 80    Glo-Djigbé                   0               0       0      0
#
#      Dessert Shop  Fast Food Restaurant  Food  Food Court  French Restaurant  \
# 107             0                     0     0           0                  0
# 89              0                     0     0           0                  0
# 233             0                     0     0           0                  0
# 251             0                     0     1           0                  0
# 173             0                     0     0           0                  0
# 148             0                     0     0           0                  0
# 223             0                     0     0           0                  0
# 50              0                     0     0           0                  0
# 104             0                     0     0           0                  0
# 80              0                     0     0           0                  0
#
#      Hardware Store  Hotel  Hotel Bar  Ice Cream Shop  Japanese Restaurant  \
# 107               0      0          0               0                    0
# 89                0      0          0               0                    0
# 233               0      0          0               0                    0
# 251               0      0          0               0                    0
# 173               0      1          0               0                    0
# 148               0      0          0               0                    0
# 223               1      0          0               0                    0
# 50                0      0          1               0                    0
# 104               0      0          0               0                    0
# 80                0      0          0               1                    0
#
#      Lounge  Middle Eastern Restaurant  Music Venue  Pier  Pizza Place  Plaza  \
# 107       0                          0            0     0            0      0
# 89        0                          1            0     0            0      0
# 233       0                          0            0     0            0      0
# 251       0                          0            0     0            0      0
# 173       0                          0            0     0            0      0
# 148       1                          0            0     0            0      0
# 223       0                          0            0     0            0      0
# 50        0                          0            0     0            0      0
# 104       0                          0            0     0            0      0
# 80        0                          0            0     0            0      0
#
#      Resort  Restaurant  Sandwich Place  Shopping Mall  Soccer Stadium  \
# 107       0           0               0              0               0
# 89        0           0               0              0               0
# 233       0           0               0              1               0
# 251       0           0               0              0               0
# 173       0           0               0              0               0
# 148       0           0               0              0               0
# 223       0           0               0              0               0
# 50        0           0               0              0               0
# 104       0           0               1              0               0
# 80        0           0               0              0               0
#
#      Tapas Restaurant  Thai Restaurant  Whisky Bar
# 107                 0                0           0
# 89                  0                0           0
# 233                 0                0           0
# 251                 0                0           0
# 173                 0                0           0
# 148                 0                0           0
# 223                 0                0           0
# 50                  0                0           0
# 104                 0                0           0
# 80                  0                0           0

# %%
AbomeyCalavi_onehot.shape
# Out:
# (332, 29)

# %%
AbomeyCalavi_grouped = AbomeyCalavi_onehot.groupby('Neighborhood').mean().reset_index()
AbomeyCalavi_grouped
# Out:
#     Neighborhood  African Restaurant  Airport Lounge    Bakery     Beach  \
# 0  Abomey-Calavi            0.027027        0.027027  0.054054  0.027027
# 1       Akassato            0.027027        0.027027  0.054054  0.027027
# 2     Glo-Djigbé            0.027027        0.027027  0.054054  0.027027
# 3        Godomey            0.027027        0.027027  0.054054  0.027027
# 4          Hévié            0.027778        0.027778  0.055556  0.027778
# 5       Kpanroun            0.027027        0.027027  0.054054  0.027027
# 6          Ouédo            0.027027        0.027027  0.054054  0.027027
# 7          Togba            0.027027        0.027027  0.054054  0.027027
# 8         Zinvié            0.027027        0.027027  0.054054  0.027027
#
#    Dessert Shop  Fast Food Restaurant      Food  Food Court  \
# 0      0.027027              0.027027  0.027027    0.027027
# 1      0.027027              0.027027  0.027027    0.027027
# 2      0.027027              0.027027  0.027027    0.027027
# 3      0.027027              0.027027  0.027027    0.027027
# 4      0.027778              0.027778  0.027778    0.027778
# 5      0.027027              0.027027  0.027027    0.027027
# 6      0.027027              0.027027  0.027027    0.027027
# 7      0.027027              0.027027  0.027027    0.027027
# 8      0.027027              0.027027  0.027027    0.027027
#
#    French Restaurant  Hardware Store     Hotel  Hotel Bar  Ice Cream Shop  \
# 0           0.027027        0.027027  0.081081   0.027027        0.027027
# 1           0.027027        0.027027  0.081081   0.027027        0.027027
# 2           0.027027        0.027027  0.081081   0.027027        0.027027
# 3           0.027027        0.027027  0.081081   0.027027        0.027027
# 4           0.027778        0.027778  0.055556   0.027778        0.027778
# 5           0.027027        0.027027  0.081081   0.027027        0.027027
# 6           0.027027        0.027027  0.081081   0.027027        0.027027
# 7           0.027027        0.027027  0.081081   0.027027        0.027027
# 8           0.027027        0.027027  0.081081   0.027027        0.027027
#
#    Japanese Restaurant    Lounge  Middle Eastern Restaurant  Music Venue  \
# 0             0.027027  0.027027                   0.054054     0.027027
# 1             0.027027  0.027027                   0.054054     0.027027
# 2             0.027027  0.027027                   0.054054     0.027027
# 3             0.027027  0.027027                   0.054054     0.027027
# 4             0.027778  0.027778                   0.055556     0.027778
# 5             0.027027  0.027027                   0.054054     0.027027
# 6             0.027027  0.027027                   0.054054     0.027027
# 7             0.027027  0.027027                   0.054054     0.027027
# 8             0.027027  0.027027                   0.054054     0.027027
#
#        Pier  Pizza Place     Plaza    Resort  Restaurant  Sandwich Place  \
# 0  0.027027     0.027027  0.054054  0.081081    0.027027        0.027027
# 1  0.027027     0.027027  0.054054  0.081081    0.027027        0.027027
# 2  0.027027     0.027027  0.054054  0.081081    0.027027        0.027027
# 3  0.027027     0.027027  0.054054  0.081081    0.027027        0.027027
# 4  0.027778     0.027778  0.055556  0.083333    0.027778        0.027778
# 5  0.027027     0.027027  0.054054  0.081081    0.027027        0.027027
# 6  0.027027     0.027027  0.054054  0.081081    0.027027        0.027027
# 7  0.027027     0.027027  0.054054  0.081081    0.027027        0.027027
# 8  0.027027     0.027027  0.054054  0.081081    0.027027        0.027027
#
#    Shopping Mall  Soccer Stadium  Tapas Restaurant  Thai Restaurant  \
# 0       0.081081        0.027027          0.027027         0.027027
# 1       0.081081        0.027027          0.027027         0.027027
# 2       0.081081        0.027027          0.027027         0.027027
# 3       0.081081        0.027027          0.027027         0.027027
# 4       0.083333        0.027778          0.027778         0.027778
# 5       0.081081        0.027027          0.027027         0.027027
# 6       0.081081        0.027027          0.027027         0.027027
# 7       0.081081        0.027027          0.027027         0.027027
# 8       0.081081        0.027027          0.027027         0.027027
#
#    Whisky Bar
# 0    0.027027
# 1    0.027027
# 2    0.027027
# 3    0.027027
# 4    0.027778
# 5    0.027027
# 6    0.027027
# 7    0.027027
# 8    0.027027

# %%
AbomeyCalavi_grouped.shape
# Out:
# (9, 29)

# %%
num_top_venues = 5

for hood in AbomeyCalavi_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = AbomeyCalavi_grouped[AbomeyCalavi_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Abomey-Calavi----
#                        venue  freq
# 0              Shopping Mall  0.08
# 1                     Resort  0.08
# 2                      Hotel  0.08
# 3  Middle Eastern Restaurant  0.05
# 4                     Bakery  0.05
#
#
# ----Akassato----
#                        venue  freq
# 0              Shopping Mall  0.08
# 1                     Resort  0.08
# 2                      Hotel  0.08
# 3  Middle Eastern Restaurant  0.05
# 4                     Bakery  0.05
#
#
# ----Glo-Djigbé----
#                        venue  freq
# 0              Shopping Mall  0.08
# 1                     Resort  0.08
# 2                      Hotel  0.08
# 3  Middle Eastern Restaurant  0.05
# 4                     Bakery  0.05
#
#
# ----Godomey----
#                        venue  freq
# 0              Shopping Mall  0.08
# 1                     Resort  0.08
# 2                      Hotel  0.08
# 3  Middle Eastern Restaurant  0.05
# 4                     Bakery  0.05
#
#
# ----Hévié----
#                        venue  freq
# 0              Shopping Mall  0.08
# 1                     Resort  0.08
# 2  Middle Eastern Restaurant  0.06
# 3                     Bakery  0.06
# 4                      Hotel  0.06
#
#
# ----Kpanroun----
#                        venue  freq
# 0              Shopping Mall  0.08
# 1                     Resort  0.08
# 2                      Hotel  0.08
# 3  Middle Eastern Restaurant  0.05
# 4                     Bakery  0.05
#
#
# ----Ouédo----
#                        venue  freq
# 0              Shopping Mall  0.08
# 1                     Resort  0.08
# 2                      Hotel  0.08
# 3  Middle Eastern Restaurant  0.05
# 4                     Bakery  0.05
#
#
# ----Togba----
#                        venue  freq
# 0              Shopping Mall  0.08
# 1                     Resort  0.08
# 2                      Hotel  0.08
# 3  Middle Eastern Restaurant  0.05
# 4                     Bakery  0.05
#
#
# ----Zinvié----
#                        venue  freq
# 0              Shopping Mall  0.08
# 1                     Resort  0.08
# 2                      Hotel  0.08
# 3  Middle Eastern Restaurant  0.05
# 4                     Bakery  0.05

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = AbomeyCalavi_grouped['Neighborhood']

for ind in np.arange(AbomeyCalavi_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(AbomeyCalavi_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#     Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0  Abomey-Calavi         Shopping Mall                Resort
# 1       Akassato         Shopping Mall                Resort
# 2     Glo-Djigbé         Shopping Mall                Resort
# 3        Godomey         Shopping Mall                Resort
# 4          Hévié         Shopping Mall                Resort
#
#   3rd Most Common Venue 4th Most Common Venue      5th Most Common Venue  \
# 0                 Hotel                Bakery                      Plaza
# 1                 Hotel                Bakery                      Plaza
# 2                 Hotel                Bakery                      Plaza
# 3                 Hotel                Bakery                      Plaza
# 4                Bakery                 Plaza  Middle Eastern Restaurant
#
#        6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0  Middle Eastern Restaurant            Whisky Bar             Hotel Bar
# 1  Middle Eastern Restaurant            Whisky Bar             Hotel Bar
# 2  Middle Eastern Restaurant            Whisky Bar             Hotel Bar
# 3  Middle Eastern Restaurant            Whisky Bar             Hotel Bar
# 4                      Hotel            Whisky Bar             Hotel Bar
#
#   9th Most Common Venue 10th Most Common Venue
# 0        Airport Lounge                  Beach
# 1        Airport Lounge                  Beach
# 2        Airport Lounge                  Beach
# 3        Airport Lounge                  Beach
# 4        Airport Lounge                  Beach

# %% [markdown]
# ## Cluster Neighborhoods
#
# Run *k*-means to cluster the neighborhood into 2 clusters.

# %%
# set number of clusters
kclusters = 2

AbomeyCalavi_grouped_clustering = AbomeyCalavi_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(AbomeyCalavi_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 0, 0, 0, 1, 0, 0, 0, 0], dtype=int32)

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

AbomeyCalavi_merged = AbomeyCalavi_df

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
AbomeyCalavi_merged = AbomeyCalavi_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

AbomeyCalavi_merged.head() # check the last columns!
# Out:
#    Department         Region   Neighborhood  Latitude  Longitude  \
# 0  Atlantique  Abomey-Calavi  Abomey-Calavi  6.450000   2.350000
# 1  Atlantique  Abomey-Calavi       Akassato  6.507371   2.365643
# 2  Atlantique  Abomey-Calavi     Glo-Djigbé  6.506988   2.331544
# 3  Atlantique  Abomey-Calavi        Godomey  6.550000   2.366667
# 4  Atlantique  Abomey-Calavi          Hévié  6.416667   2.250000
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0               0         Shopping Mall                Resort
# 1               0         Shopping Mall                Resort
# 2               0         Shopping Mall                Resort
# 3               0         Shopping Mall                Resort
# 4               1         Shopping Mall                Resort
#
#   3rd Most Common Venue 4th Most Common Venue      5th Most Common Venue  \
# 0                 Hotel                Bakery                      Plaza
# 1                 Hotel                Bakery                      Plaza
# 2                 Hotel                Bakery                      Plaza
# 3                 Hotel                Bakery                      Plaza
# 4                Bakery                 Plaza  Middle Eastern Restaurant
#
#        6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0  Middle Eastern Restaurant            Whisky Bar             Hotel Bar
# 1  Middle Eastern Restaurant            Whisky Bar             Hotel Bar
# 2  Middle Eastern Restaurant            Whisky Bar             Hotel Bar
# 3  Middle Eastern Restaurant            Whisky Bar             Hotel Bar
# 4                      Hotel            Whisky Bar             Hotel Bar
#
#   9th Most Common Venue 10th Most Common Venue
# 0        Airport Lounge                  Beach
# 1        Airport Lounge                  Beach
# 2        Airport Lounge                  Beach
# 3        Airport Lounge                  Beach
# 4        Airport Lounge                  Beach

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(AbomeyCalavi_merged['Latitude'], AbomeyCalavi_merged['Longitude'], AbomeyCalavi_merged['Neighborhood'], AbomeyCalavi_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
AbomeyCalavi_merged.loc[AbomeyCalavi_merged['Cluster Labels'] == 0, AbomeyCalavi_merged.columns[[2] + list(range(5, 9))]]
# Out:
#     Neighborhood  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0  Abomey-Calavi               0         Shopping Mall                Resort
# 1       Akassato               0         Shopping Mall                Resort
# 2     Glo-Djigbé               0         Shopping Mall                Resort
# 3        Godomey               0         Shopping Mall                Resort
# 5       Kpanroun               0         Shopping Mall                Resort
# 6          Ouédo               0         Shopping Mall                Resort
# 7          Togba               0         Shopping Mall                Resort
# 8         Zinvié               0         Shopping Mall                Resort
#
#   3rd Most Common Venue
# 0                 Hotel
# 1                 Hotel
# 2                 Hotel
# 3                 Hotel
# 5                 Hotel
# 6                 Hotel
# 7                 Hotel
# 8                 Hotel

# %%
AbomeyCalavi_merged.loc[AbomeyCalavi_merged['Cluster Labels'] == 1, AbomeyCalavi_merged.columns[[2] + list(range(5, 9))]]
# Out:
#   Neighborhood  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 4        Hévié               1         Shopping Mall                Resort
#
#   3rd Most Common Venue
# 4                Bakery

# %% [markdown]
# We could notice here from the clustering of neighborhood in the southern part we have more of shopping mall, resort and hotels venue.
# Which is understandable since this part of the country is in consistent development and very frequented by young people and foreigners.
